# %% [markdown]
# # PRODIGY TASK 02

# %% [markdown]
# ## PROBLEM STATEMENT-
#  Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, such as the Titanic dataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('https://raw.githubusercontent.com/aishwaryadatascience/PRODIGY-TASK-02/main/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Dropping unnecessary columns
df.drop(columns= "Cabin", axis=1, inplace= True)

# %%
# Filling the missing values
df['Age'].fillna(df['Age'].mean(), inplace= True)

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace= True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# * All missing values are treated.

# %%
# Checking duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * There is no duplicate value.

# %% [markdown]
# ### CHECKING THE SURVIVAL OF PEOPLE

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ## DATA VIZUALIZATION

# %% [markdown]
# ### COUNTPLOT

# %%
sns.countplot(x= 'Survived', data=df, palette= 'viridis',)
plt.xlabel("Survival Status")
plt.ylabel("Number of People")
plt.xticks(ticks= [0,1], labels= ['Not Survived', 'Survived'])
plt.show()

# %% [markdown]
# ### PIECHART

# %%
plt.pie(df['Survived'].value_counts(), explode= [0,0.04], autopct= "%1.2f%%", labels= ['Not Survived', 'Survived'])
plt.title("Survival of People")
plt.show()

# %% [markdown]
# ### SURVIVED FROM DIFFERENT GENDER

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
sns.countplot(x= 'Sex', data= df, palette= 'magma',)
plt.xlabel("Gender")
plt.ylabel("Number of People")
plt.show()

# %%
sns.countplot(x= 'Survived', hue= 'Sex', data= df, palette= 'mako',)
plt.xlabel("Survival of People")
plt.ylabel("Number of People")
plt.xticks(ticks= [0,1], labels= ['Not Survived', 'Survived'])
plt.show()

# %%
df[df['Sex']== 'male'].Survived.groupby(df.Survived).count().plot(kind= 'pie',
figsize= (3,6), explode= [0,0.05], autopct= '%1.1f%%', labels= ["Not Survived", "Survived"])
plt.ylabel("")
plt.title("Male Survival Rate")
plt.show()

# %%
df[df['Sex']== 'female'].Survived.groupby(df.Survived).count().plot(kind= 'pie',
figsize= (3,6), explode= [0,0.05], autopct= '%1.1f%%', labels= ["Not Survived", "Survived"])
plt.ylabel("")
plt.title("Female Survival Rate")
plt.show()

# %% [markdown]
# * Survival rate in Female was much more higher than Male.

# %% [markdown]
# ### POPULATION OF DIFFERENT PASSENGER CLASS

# %%
sns.countplot(x= 'Pclass', data= df, palette= 'flare',)
plt.xlabel("Pclass")
plt.ylabel("Number of People")
plt.show()

# %% [markdown]
# ### PEOPLE SURVIVED FROM DIFFERENT PASSENGER CLASS

# %%
sns.countplot(x='Survived', hue= 'Pclass', data= df, palette= 'crest',)
plt.xlabel("Survival Status")
plt.ylabel("Number of People")
plt.xticks(ticks= [0,1], labels= ['Nor Survived', 'Survived'])
plt.show()

# %%
sns.catplot(x= 'Pclass', hue= 'Survived', col= 'Sex', kind= 'count', data= df,
palette= 'rocket_r')
plt.tight_layout()

# %% [markdown]
# * Though population of Pclass 3 was the highest, yet they had the least survival rate.
# * Males from Pclass 3 had the least survival rate.

# %% [markdown]
# ### PEOPLE SURVIVED FROM DIFFERENT EMBARKMENT

# %%
sns.countplot(x= 'Embarked', data= df, palette= 'coolwarm',)
plt.xlabel("Embarked")
plt.ylabel("Number of People")
plt.show()

# %%
sns.countplot(x='Survived', hue= 'Embarked', data= df, palette= 'Set2',)
plt.xlabel("Survival Status")
plt.ylabel("Number of People")
plt.xticks(ticks= [0,1], labels= ['Nor Survived', 'Survived'])
plt.show()

# %%
fig,axes= plt.subplots(1,2, figsize= (12,6))
sns.countplot(x= 'SibSp', data= df, ax= axes[0], palette= 'hls')
sns.countplot(x= 'Parch', data= df, ax= axes[1], palette= 'hls')
plt.show()

# %%
sns.countplot(x= 'Survived', hue= 'SibSp', data= df, palette= 'Paired')
plt.xticks(ticks= [0,1], labels= ['Not survived', 'Survived'])
plt.xlabel("Survival Status")
plt.ylabel("Number of People")
plt.title("Survival Population of SibSp")
plt.show()

sns.countplot(x= 'Survived', hue= 'Parch', data= df, palette= 'Paired')
plt.xticks(ticks= [0,1], labels= ['Not survived', 'Survived'])
plt.xlabel("Survival Status")
plt.ylabel("Number of People")
plt.title("Survival Population of Parch")
plt.show()

# %% [markdown]
# ### DISTRIBUTION OF FARE AND AGE

# %%
fig,axes= plt.subplots(1,2, figsize= (12,6))
sns.histplot(df['Fare'], kde= True, ax= axes[0])
sns.histplot(df['Age'].dropna(), kde= True, ax= axes[1])
plt.show()

# %% [markdown]
# ### SURVIVAL RATE IN DIFFERENT AGE GROUP

# %%
# Defining cut points & label names

cut_points= [0,5,12,18,35,60,100]
label_names= ['Infant', 'Child', 'Teenager', 'Young Adult', 'Adult', 'Senior']

# Creating the Age categories in column
df['Age_categories']= pd.cut(df['Age'], bins= cut_points, labels= label_names, right= False)

# Creating a pivot table for survivalnrates 
age_pivot= df.pivot_table(index= "Age_categories", values= "Survived")

# Defining colors for each bar
colors= ['blue', 'green', 'orange', 'purple', 'pink', 'brown']

# Plotting the bar chart 
fig, ax= plt.subplots()
bars= ax.bar(age_pivot.index, age_pivot['Survived'], color= colors)

# Adding legend
handles= [plt.Rectangle((0,0), 1,1, color= colors[i]) for i in
range(len(colors))]
ax.legend(handles, label_names)
ax.set_title('Survival Rates by Age Category')
ax.set_xlabel('Age Category')
ax.set_ylabel('Survival Rate')
plt.xticks(rotation= 40)
plt.show()

# %% [markdown]
# * Young Adults had the least survival rate

# %%
sns.histplot(x= 'Fare', hue= 'Survived', data= df, kde= True)
plt.legend(labels= ['Survived', 'Not Survived'])
plt.show()

# %%
sns.histplot(x= 'Age', hue= 'Survived', data= df, kde= True)
plt.legend(labels= ['Survived', 'Not Survived'])
plt.show()

# %% [markdown]
# ### CORRELATION

# %%
df.replace({'Sex':{'Male':1, 'Female':0}, 'Embarked':{'S':0, 'C':1, 'Q':2}}, inplace= True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  Embarked Age_categories
# 0      0         A/5 21171   7.2500         0    Young Adult
# 1      0          PC 17599  71.2833         1          Adult
# 2      0  STON/O2. 3101282   7.9250         0    Young Adult
# 3      0            113803  53.1000         0          Adult
# ...

# %%
df_num= df[['Fare', 'Parch', 'SibSp', 'Age', 'Sex', 'Pclass', 'Embarked', 'Survived']]

# %%
sns.heatmap(df_num.corr(), annot= True)
plt.show()

# %%
* Fare

# %%
Fare, sex, Pclass, Embarked has correlation with survived column
